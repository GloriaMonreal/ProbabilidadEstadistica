# %% [markdown]
# <a href="https://colab.research.google.com/github/GloriaMonreal/ProbabilidadEstadistica/blob/main/Unidad%201/U1_Practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Instituto Tecnologico de Mexico Campus Durango**
#
# Ing.Sistemas Computacionales
#
# ##**Unidad 1**
#
# # **Probabilidad y Estadistica**
#
# ### Practica 1: Estadistica Descriptiva Basica e Histogramas
#
# **Alumnos**:
# Gloria Angelica Monreal Muñoz
#
# Emmanuel Fernando Alcala Acosta
#
#
# **Docente:**
# José Gabriel Rodríguez Rivas
#
#
# ![image.png](data:image/png;base64,...)

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50,100), 2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [70.23, 67.48, 57.37, 52.57, 84.19, 85.4, 57.98, 68.35, 89.68, 92.5, 55.59, 56.12, 90.96, 83.94, 57.85, 56.63, 79.28, 60.6, 87.26, 86.35, 81.41, 90.84, 80.11, 66.7, 68.25, 70.2, 97.62, 85.56, 54.69, 87.33, 52.02, 98.95, 60.58, 53.9, 53.32, 57.74, 87.97, 99.66, 85.76, 96.39, 72.08, 89.12, 88.42, 50.74, 98.33, 78.24, 80.29, 72.28, 88.48, 62.75, 60.21, 77.64, 94.15, 73.92, 77.24, 95.56, 82.85, 91.89, 64.01, 91.05, 57.68, 70.28, 74.49, 85.32, 57.51, 89.75, 83.82, 59.97, 62.8, 88.69, 67.26, 79.12, 71.86, 55.96, 86.35, 63.14, 61.53, 58.71, 95.07, 63.0, 83.33, 50.26, 72.11, 60.55, 94.49, 79.08, 77.29, 69.41, 66.62, 73.88, 77.08, 96.12, 53.29, 81.5, 72.52, 85.6, 79.88, 60.23, 79.9, 57.7]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50,100), 2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [84.19, 83.6, 92.27, 96.15, 90.14, 68.51, 85.01, 62.26, 60.03, 73.22, 69.88, 55.94, 73.27, 61.94, 82.9, 72.49, 98.59, 85.65, 98.75, 69.14, 85.07, 61.04, 95.29, 76.86, 77.68, 80.72, 69.04, 54.13, 89.79, 95.75, 99.6, 81.61, 94.09, 65.32, 89.56, 61.59, 58.46, 96.96, 65.02, 59.19, 75.94, 57.72, 78.26, 78.49, 92.96, 68.4, 78.31, 50.26, 64.64, 87.79, 58.38, 75.33, 62.85, 62.4, 58.21, 94.31, 54.92, 86.92, 59.07, 83.05, 76.31, 88.98, 62.16, 80.73, 96.65, 79.54, 66.27, 56.53, 71.66, 97.58, 65.18, 56.0, 63.85, 84.81, 81.56, 97.83, 81.06, 94.07, 51.49, 79.03, 97.51, 98.73, 93.18, 87.53, 78.07, 55.51, 80.4, 52.54, 99.38, 72.07, 58.08, 83.93, 71.22, 94.56, 67.67, 81.0, 76.39, 59.71, 60.34, 75.88]

# %%
maximo1 = max(fabrica1)
minimo1 = min(fabrica1)
rango1 = maximo1 - minimo1
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

print ("Estadistica descriptiva de la Fabrica 1 \n", "\n Media: ", media1,
       "\n Mediana: ", mediana1, "\n Moda: ", moda1, "\n Maximo: ", maximo1,
       "\n Minimo: ", minimo1, "\n Rango: ", rango1)
# Out:
# Estadistica descriptiva de la Fabrica 1
#
#  Media:  74.6173
#  Mediana:  75.785
#  Moda:  86.35
#  Maximo:  99.66
#  Minimo:  50.26
#  Rango:  49.4

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo2 - minimo2
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print ("Estadistica descriptiva de la Fabrica 2 \n", "\n Media: ", media2,
       "\n Mediana: ", mediana2, "\n Moda: ", moda2, "\n Maximo: ", maximo2,
       "\n Minimo: ", minimo2, "\n Rango: ", rango2)
# Out:
# Estadistica descriptiva de la Fabrica 2
#
#  Media:  76.239
#  Mediana:  77.27000000000001
#  Moda:  84.19
#  Maximo:  99.6
#  Minimo:  50.26
#  Rango:  49.339999999999996

# %% [markdown]
# # Dispersion de los datos

# %%
desviacion_estandar_fabrica1 = stdev(fabrica1)
print(desviacion_estandar_fabrica1)
# Out:
# 14.087569694915121

# %%
desviacion_estandar_fabrica2 = stdev(fabrica2)
print(desviacion_estandar_fabrica2)
# Out:
# 14.210768039864288

# %%
plt.figure(figsize= (8,6) )
plt.hist(fabrica1,bins=10,alpha=0.2, color="b", edgecolor="black")
plt.axvline(media1,color="b",linestyle="dashed",linewidth=2,label=f"Media: {media1:.2f}")
plt.axvline(mediana1,color="r",linestyle="dashed",linewidth=2,label=f"Mediana: {mediana1:.2f}")
plt.axvline(moda1,color="y",linestyle="dashed",linewidth=2,label=f"Moda: {moda1:.2f}")

plt.axvline(media1 - desviacion_estandar_fabrica1,color= "black",linestyle= "dashed",linewidth= 2,label= f"Desv.Estandar: {desviacion_estandar_fabrica1:.2f}")
plt.axvline(media1+desviacion_estandar_fabrica1,color="black",linestyle="dashed",linewidth=2)

plt.xlabel("Valor")
plt.ylabel("Frecuencia")
plt.title("Produccion diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.figure(figsize= (8,6) )
plt.hist(fabrica2,bins=10,alpha=0.2, color="b", edgecolor="black")
plt.axvline(media2,color="b",linestyle="dashed",linewidth=2,label=f"Media: {media2:.2f}")
plt.axvline(mediana2,color="r",linestyle="dashed",linewidth=2,label=f"Mediana: {mediana2:.2f}")
plt.axvline(moda2,color="y",linestyle="dashed",linewidth=2,label=f"Moda: {moda2:.2f}")

plt.axvline(media2 - desviacion_estandar_fabrica2,color= "black",linestyle= "dashed",linewidth= 2,label= f"Desv.Estandar: {desviacion_estandar_fabrica2:.2f}")
plt.axvline(media2+desviacion_estandar_fabrica2,color="black",linestyle="dashed",linewidth=2)

plt.xlabel("Valor")
plt.ylabel("Frecuencia")
plt.title("Produccion diaria de la fabrica 2")
plt.legend()
plt.show()

# %% [markdown]
# #Densidad

# %%
import seaborn as sns

# %%
#La densidad grafica es una forma de visualizar la distribucion de datos en un
#intervalo o periodo de tiempo continuo
#Se trata de un histograma que usa el suavisado de kernel para trazar valores,
#lo que permite obtener distribuciones mas suaves al reducir el ruido
#Una curva de densidad muestra la ubicacion de la media y la mediana de una
#distribucion

sns.histplot( x = fabrica1, kde = True, kde_kws = {'bw_adjust': 0.5}, bins = 10)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot( x = fabrica2, kde = True, kde_kws = {'bw_adjust': 0.5}, bins = 10)
# Out:
# <Axes: ylabel='Count'>
