# %% [markdown]
# <a href="https://colab.research.google.com/github/GloriaMonreal/ProbabilidadEstadistica/blob/main/Unidad%201/U1_Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Instituto Tecnologico de Mexico Campus Durango
#
# Ing.Sistemas Computacionales
#
# # Probabilidad y Estadistica
#
# # **Practica 1**
#
# **Alumno**:
# Gloria Angelica Monreal Muñoz
#
# **Docente:**
# José Gabriel Rodríguez Rivas
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Ejemplo 1:

# %%
from statistics import *
#Formar una lista de calificaciones
grupoa = [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
print(grupoa)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

# %%
type(grupoa)
# Out:
# list

# %%
#Sacar la media de la lista de calificaciones con una formula

promedio = sum(grupoa)/len(grupoa)
print(promedio)
# Out:
# 75.33333333333333

# %%
#Sacar mediana a partir de "mean"
promedio2 = mean(grupoa)
print(promedio2)
# Out:
# 75.33333333333333

# %%
#Determinar el valor de la mediana

mediana = median(grupoa)
print(mediana)
# Out:
# 76.5

# %%
#Determinar el valor de la moda

moda = mode(grupoa)
print(moda)
# Out:
# 70

# %%
#En caso de existir mas de 1 moda, se puede emplear la muncion multimode para sacar todas las modas existentes

moda2 = multimode(grupoa)
print(moda2)
# Out:
# [70, 100]

# %% [markdown]
# ###Ejemplo 2. Tiempos de 100 mtrs de un grupo de 12 alumnos

# %%
tiempos100mts = [15.10, 17.20, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.10, 17.20]

#Desplegamos la lista
print(tiempos100mts)
# Out:
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]

# %%
#Usamos la funcion para determinar el promedio
print("El tiempo promedio de los corredores es: ", mean(tiempos100mts))
# Out:
# El tiempo promedio de los corredores es:  17.322

# %%
#Definimos una variable "mediana" para calcular la mediana de la lista
mediana = median(tiempos100mts)
print("La media de los tiempos de los corredores es: ", mediana)
# Out:
# La media de los tiempos de los corredores es:  17.2

# %%
#Definimos una variable "moda" para calcular la moda de la lista
moda = mode(tiempos100mts)
print("La moda de los tiempos de los corredores es: ", moda)
# Out:
# La moda de los tiempos de los corredores es:  15.1

# %%
#Usamos "multimode" en caso de que sea bimodal o multimodal
multimoda = multimode(tiempos100mts)
print("Las modas de los tiempos de los corredores son: ", multimoda)
# Out:
# Las modas de los tiempos de los corredores son:  [15.1, 17.2]

# %% [markdown]
# ##Ejemplo 3: Histograma de 2 grupos

# %%
#Libreria para generar numeros aleatorios
import random

# %%
fabrica1 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50, 100), 2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [95.19, 70.86, 93.41, 52.47, 69.2, 67.1, 92.18, 84.61, 60.61, 95.45, 98.63, 61.39, 61.91, 92.22, 77.4, 77.02, 90.57, 65.49, 52.29, 58.76, 60.85, 56.2, 93.72, 93.99, 69.8, 51.77, 67.93, 70.02, 51.34, 72.6, 69.45, 56.99, 52.03, 84.35, 55.02, 66.38, 82.97, 68.54, 90.71, 57.09, 82.99, 55.1, 92.32, 77.1, 64.22, 58.54, 96.49, 81.3, 54.66, 84.4, 62.08, 54.43, 98.36, 64.01, 53.29, 54.1, 52.81, 92.7, 54.77, 82.16, 58.26, 81.72, 87.93, 73.53, 98.75, 74.73, 66.55, 86.81, 56.1, 93.19, 95.03, 73.72, 66.63, 68.74, 60.64, 94.0, 63.14, 81.2, 62.32, 77.86, 83.98, 67.1, 99.27, 89.25, 65.81, 68.19, 82.81, 53.8, 79.47, 66.56, 98.71, 93.1, 63.6, 80.25, 91.64, 76.76, 95.9, 68.01, 70.48, 88.86]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio2 = round(random.uniform(50, 100), 2)
  fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [62.38, 65.94, 92.89, 97.85, 54.33, 91.42, 89.38, 75.0, 83.11, 91.31, 60.29, 67.66, 84.05, 51.58, 83.24, 95.18, 64.89, 93.65, 98.04, 58.65, 56.5, 88.98, 77.22, 97.14, 64.57, 91.98, 96.51, 57.64, 89.51, 94.59, 82.18, 70.87, 69.7, 54.15, 78.98, 81.56, 75.2, 94.13, 74.52, 54.57, 98.61, 81.17, 98.17, 68.97, 79.23, 69.92, 89.14, 83.73, 52.1, 75.87, 93.15, 61.56, 86.12, 83.02, 61.11, 78.02, 65.92, 71.72, 94.01, 93.18, 69.99, 56.98, 85.02, 84.15, 60.41, 71.58, 92.67, 74.36, 71.75, 89.06, 65.91, 92.95, 80.28, 51.87, 54.52, 97.23, 50.86, 99.47, 90.17, 92.74, 75.56, 97.55, 97.87, 61.52, 68.61, 59.0, 51.99, 99.28, 98.25, 79.97, 54.73, 56.67, 52.6, 53.57, 61.45, 81.16, 53.12, 90.04, 77.0, 66.13]

# %%
#Libreria de python para graficar valores
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title("Produccion diaria de la Fabrica 1")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la Fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("Produccion diaria de la Fabrica 2")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la Fabrica 2')

# %%
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

print("Valores de la Fabrica 1")
print("La media es: ", media1)
print("La mediana es: ", mediana1)
print("La moda es: ", moda1)
# Out:
# Valores de la Fabrica 1
# La media es:  74.0874
# La mediana es:  70.67
# La moda es:  67.1

# %%
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print("Valores de la Fabrica 2")
print("La media es: ", media2)
print("La mediana es: ", mediana2)
print("La moda es: ", moda2)
# Out:
# Valores de la Fabrica 2
# La media es:  76.641
# La mediana es:  77.62
# La moda es:  62.38

# %%
# generar 2 subplot de 1 renglon por 2 columnas para desplegar los 2 histogramas una al lado de la otra
fig, (ax1, ax2) = plt.subplots(nrows =1, ncols =2, figsize =(10, 5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
plt.hist(fabrica1, bins = 10, alpha = 0.2, color = "b", edgecolor = "black")
plt.axvline(media1, color = "b", linestyle = "dashed", linewidth = 2, label = "Media")
plt.axvline(mediana1, color = "r", linestyle = "dashed", linewidth = 2, label = "Mediana")
plt.axvline(moda1, color = "y", linestyle = "dashed", linewidth = 2, label = "Moda")
plt.xlabel("Valor")
plt.ylabel("Frecuencia")
plt.title("Produccion diaria de la Fabrica 1")
plt.legend()
plt.show()

# %%
plt.hist(fabrica2, bins = 10, alpha = 0.2, color = "b", edgecolor = "black")
plt.axvline(media2, color = "b", linestyle = "dashed", linewidth = 2, label = "Media")
plt.axvline(mediana2, color = "r", linestyle = "dashed", linewidth = 2, label = "Mediana")
plt.axvline(moda2, color = "y", linestyle = "dashed", linewidth = 2, label = "Moda")
plt.xlabel("Valor")
plt.ylabel("Frecuencia")
plt.title("Produccion diaria de la Fabrica 2")
plt.legend()
plt.show()
